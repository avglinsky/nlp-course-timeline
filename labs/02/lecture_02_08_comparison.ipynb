# %%
import pandas as pd

data = {
    "Метод оптимизации": ["Momentum", "Nesterov Momentum", "Adagrad", "RMSprop", "Adam"],
    "Плюсы": [
        "Сглаживает шумные градиенты, Ускоряет сходимость вдоль оси градиента",
        "Улучшенная версия Momentum, Учитывает будущее направление градиента",
        "Адаптивная скорость обучения для каждого параметра, Эффективно в работе с разреженными данными",
        "Адаптивная скорость обучения с экспоненциальным сглаживанием, Работает хорошо на многих задачах",
        "Комбинирует метод моментов и адаптивную скорость обучения, Широко используется в практике",
    ],
    "Минусы": [
        "Может пропустить минимум из-за инерции, Может сходиться к плохому локальному минимуму",
        "Требует настройки параметров, Может потребовать больше вычислительных ресурсов",
        "Требует настройки параметра epsilon, Может уменьшать скорость обучения слишком быстро",
        "Требует настройки параметров, Может замедлить сходимость в случае неправильной настройки",
        "Требует настройки параметров, Может быть чувствительным к начальным значениям",
    ],
    "Примечания": ["-", "-", "-", "-", "-"],
}

df = pd.DataFrame(data)

# Выводим таблицу pandas
print(df)
# Out:
#    Метод оптимизации                                              Плюсы  \
# 0           Momentum  Сглаживает шумные градиенты, Ускоряет сходимос...
# 1  Nesterov Momentum  Улучшенная версия Momentum, Учитывает будущее ...
# 2            Adagrad  Адаптивная скорость обучения для каждого парам...
# 3            RMSprop  Адаптивная скорость обучения с экспоненциальны...
# 4               Adam  Комбинирует метод моментов и адаптивную скорос...
#
#                                               Минусы Примечания
# 0  Может пропустить минимум из-за инерции, Может ...          -
# 1  Требует настройки параметров, Может потребоват...          -
# 2  Требует настройки параметра epsilon, Может уме...          -
# 3  Требует настройки параметров, Может замедлить ...          -
# 4  Требует настройки параметров, Может быть чувст...          -
